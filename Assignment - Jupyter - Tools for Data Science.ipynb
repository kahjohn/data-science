# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Name: Low Kah John**
#
# Current job: Data Engineer
#
# Desire job: Data Scientist

# %% [markdown]
# *I am interested in data science because my career plan is to explore all data related position. I had tried with data analysts, currently as data engineer and lastly will be data scientist*

# %% [markdown]
# ### Below code is to print a complete sentence with an assigned variable.

# %%
test=27

print("I'm aged of ", test, ".")
# Out:
# I'm aged of  27 .

# %% [markdown]
# **Hyperlink**
# <a href="https://dataplatform.cloud.ibm.com/gallery">IBM Cloud Gallery</a>
#
# **Numbered list**
# <ol>
# <li>Fish</li>
# <li>Eggs</li>
# <li>Cheese</li>
# </ol>
#
# **Table**
# | header | header |
# | ------ | ------ |
# | cell | cell |
